# %%
1
# Out:
# Running cells with '.venv (Python 3.11.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Administrator/OneDrive - Georgia Institute of Technology/MSA/Coursework/Fall'25/CS 7641/Project/OOS-Product-Recommendation-Engine/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
